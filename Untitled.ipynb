# %%
import os
print(os.getcwd())
# Out:
# C:\Users\risha\diabetes_project

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'app.py', 'diabetes.csv', 'diabetes.ipynb', 'diabetes_ann_model.keras', 'diabetes_scaler.pkl', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
import sys

# !{sys.executable} -m pip install streamlit

# %%
import sys

# !{sys.executable} -m pip install tensorflow scikit-learn pandas numpy joblib

# %%
import sys

# !{sys.executable} -m streamlit run app.py
